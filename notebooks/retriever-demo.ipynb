# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

# %%
from src.retriever import retrieve
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from src.retriever import retrieve
#
# File c:\Users\Bisrat\Documents\intelligent-complaint-analysis\src\retriever.py:11
#       7 model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
#      10 # Load FAISS index
# ---> 11 index = faiss.read_index("vector_store/complaints.index")
#      14 # Load metadata
#      15 metadata = pd.read_csv("vector_store/chunk_metadata.csv")
#
# File c:\Users\Bisrat\AppData\Local\Programs\Python\Python312\Lib\site-packages\faiss\swigfaiss.py:13446, in read_index(*args)
#   13445 def read_index(*args):
# > 13446     return _swigfaiss.read_index(*args)
#
# RuntimeError: Error in __cdecl faiss::FileIOReader::FileIOReader(const char *) at D:\a\faiss\faiss\faiss\impl\io.cpp:70: Error: 'f' failed: could not open vector_store/complaints.index for reading: No such file or directory

# %%
retrieve(
    "Why are customers complaining about unauthorized credit card charges?"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 retrieve(
#       2     "Why are customers complaining about unauthorized credit card charges?"
#       3 )
#
# NameError: name 'retrieve' is not defined
